# %%
import numpy as np
N_test = [10,13,20,30,40,50,60]
h_test = [1/10,1/13,1/20,1/30,1/40,1/50,1/60,1/100]
log_h_test = np.log(h_test)
error = [0.0009288815447982453,
        0.0005523950389288928,

        0.00023437045178610166,
        0.00010434316609012601,
        5.8728243305517976e-05,
        3.759651410176879e-05,
        2.6112629399215235e-05,
        9.402609873605333e-06
]
log_error = np.log(error)
import matplotlib.pyplot as plt

# %%
plt.xlabel("h")
plt.ylabel("error L2")
plt.plot(h_test,error, marker = 'o')

# %%
plt.figure(figsize = (6,6))
plt.xlabel("log h")
plt.ylabel("log (error L2)")
plt.plot(log_h_test,log_error, marker = 'o')
